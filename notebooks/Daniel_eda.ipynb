# %%
import pandas as pd
import matplotlib.pylab as plt
import matplotlib.dates as mdates

# %%
df = pd.read_csv("/Users/sa22/Downloads/EVENTS_RAW-US-f2912929-edc6-4c32-820a-1d45015585a7-2025-02-01_194003.csv")
df.shape
# Out:
# /var/folders/d3/gvkrf42n6cs_vbsl97177w3m0000gn/T/ipykernel_94700/946688990.py:1: DtypeWarning: Columns (2,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/sa22/Downloads/EVENTS_RAW-US-f2912929-edc6-4c32-820a-1d45015585a7-2025-02-01_194003.csv")
# (101781, 77)

# %%
df.head(20)
# Out:
#              EVENT_ID                                         EVENT_NAME  \
# 0      rZ7HnEZ1AfF6aK                             Tonight at the Improv!
# 1      rZ7HnEZ1AfF6aN                             Tonight at the Improv!
# 2     1ApZkFMGkdiw0WO                                            Kneecap
# 3      rZ7HnEZ1AfF6aS                             Tonight at the Improv!
# 4      rZ7HnEZ1AfF6ad                             Tonight at the Improv!
# 5       G5ezZb8MgIPuh                             Cirque du Soleil : "O"
# 6    1avjZbx8ouIZd271                                      The Mentalist
# 7   vv1keZv-4YGA1U7Bv  Gutfeld Live '25 Featuring Greg Gutfeld & spec...
# 8       k7vGFb8zt7yQJ             Irish Celebration Starring Andy Cooney
# 9       15vjZbx8KayCZ                                      The Mentalist
# 10     vvG1VZb41CZdEo               bbno$: it's pronounced baby no money
# 11      k7vGFb45tn6T5                                            Jordana
# ...

# %%
df.describe()
# Out:
#           MIN_PRICE     MAX_PRICE  VENUE_LATITUDE  VENUE_LONGITUDE  \
# count  58965.000000  58965.000000   101718.000000    101718.000000
# mean      44.092417    135.683085       37.598118       -94.564501
# std       40.883470    407.095267        4.727901        18.994937
# min        0.000000      0.000000      -87.713192      -159.371111
# 25%       24.190000     35.000000       35.955298      -115.170811
# 50%       38.160000     75.000000       37.775500       -88.377197
# 75%       55.000000    126.500000       40.759914       -76.278038
# max     3216.000000  21000.000000       64.503700       122.269633
#
#        RESALE_EVENT_URL  PRESALE_NAME  PRESALE_DATETIME_RANGE  \
# count               0.0           0.0                     0.0
# mean                NaN           NaN                     NaN
# std                 NaN           NaN                     NaN
# min                 NaN           NaN                     NaN
# ...

# %%
df.columns
# Out:
# Index(['EVENT_ID', 'EVENT_NAME', 'EVENT_NOTES', 'EVENT_INFO', 'EVENT_STATUS',
#        'EVENT_START_DATETIME', 'EVENT_END_DATETIME', 'EVENT_START_LOCAL_DATE',
#        'EVENT_START_LOCAL_TIME', 'ONSALE_START_DATETIME',
#        'ONSALE_END_DATETIME', 'CLASSIFICATION_SEGMENT', 'CLASSIFICATION_GENRE',
#        'CLASSIFICATION_SUB_GENRE', 'EVENT_IMAGE_URL', 'MIN_PRICE', 'MAX_PRICE',
#        'CURRENCY', 'ATTRACTION_NAME', 'ATTRACTION_ID', 'ATTRACTION_IMAGE_URL',
#        'VENUE_NAME', 'VENUE_ID', 'VENUE_STREET', 'VENUE_CITY',
#        'VENUE_STATE_CODE', 'VENUE_COUNTRY_CODE', 'VENUE_LATITUDE',
#        'VENUE_LONGITUDE', 'VENUE_ZIP_CODE', 'VENUE_TIMEZONE', 'ATTRACTION_URL',
#        'VENUE_URL', 'PRIMARY_EVENT_URL', 'RESALE_EVENT_URL', 'PRESALE_NAME',
#        'PRESALE_DATETIME_RANGE', 'LEGACY_EVENT_ID', 'LEGACY_VENUE_ID',
#        'LEGACY_ATTRACTION_ID', 'PRESALE_NAME.1', 'PRESALE_DESCRIPTION',
#        'PRESALE_START_DATETIME', 'PRESALE_END_DATETIME', 'SOURCE',
# ...

# %%
# check how many events may be duplicated, by ID
df['EVENT_ID'].duplicated().sum()
# Out:
# 0

# %%
# reassigning df commenting out unnecessary columns

df = df[[#'EVENT_ID', 'EVENT_NAME', 'EVENT_NOTES', 'EVENT_INFO', 'EVENT_STATUS',
       #'EVENT_START_DATETIME', 'EVENT_END_DATETIME', 'EVENT_START_LOCAL_DATE',
       #'EVENT_START_LOCAL_TIME', 
        'ONSALE_START_DATETIME','ONSALE_END_DATETIME', 
        #'CLASSIFICATION_SEGMENT', 'CLASSIFICATION_GENRE',
       #'CLASSIFICATION_SUB_GENRE', 'EVENT_IMAGE_URL', 'MIN_PRICE', 
       'MAX_PRICE',
       #'CURRENCY', 'ATTRACTION_NAME', 'ATTRACTION_ID', 'ATTRACTION_IMAGE_URL',
       #'VENUE_NAME', 'VENUE_ID', 'VENUE_STREET', 'VENUE_CITY',
       #'VENUE_STATE_CODE', 'VENUE_COUNTRY_CODE', 'VENUE_LATITUDE',
       #'VENUE_LONGITUDE', 'VENUE_ZIP_CODE', 'VENUE_TIMEZONE', 'ATTRACTION_URL',
       #'VENUE_URL', 'PRIMARY_EVENT_URL', 'RESALE_EVENT_URL', 'PRESALE_NAME',
       #'PRESALE_DATETIME_RANGE', 'LEGACY_EVENT_ID', 'LEGACY_VENUE_ID',
       #'LEGACY_ATTRACTION_ID', 'PRESALE_NAME.1', 'PRESALE_DESCRIPTION',
       #'PRESALE_START_DATETIME', 'PRESALE_END_DATETIME', 'SOURCE',
       #'CLASSIFICATION_TYPE', 'CLASSIFICATION_SUB_TYPE', 'PROMOTER_ID',
       #'PROMOTER_NAME', 'CLASSIFICATION_SEGMENT_ID', 'CLASSIFICATION_GENRE_ID',
       #'CLASSIFICATION_SUB_GENRE_ID', 'CLASSIFICATION_TYPE_ID',
       #'CLASSIFICATION_SUB_TYPE_ID', 'ATTRACTION_CLASSIFICATION_SEGMENT_ID',
       #'ATTRACTION_CLASSIFICATION_SEGMENT',
       #'ATTRACTION_CLASSIFICATION_GENRE_ID', 'ATTRACTION_CLASSIFICATION_GENRE',
       #'ATTRACTION_CLASSIFICATION_SUB_GENRE_ID',
       #'ATTRACTION_CLASSIFICATION_SUB_GENRE',
       #'ATTRACTION_CLASSIFICATION_TYPE_ID', 'ATTRACTION_CLASSIFICATION_TYPE',
       #'ATTRACTION_CLASSIFICATION_SUB_TYPE_ID',
       #'ATTRACTION_CLASSIFICATION_SUB_TYPE', 'MIN_PRICE_WITH_FEES',
       #'MAX_PRICE_WITH_FEES', 'TRANSACTABLE', 'HOT_EVENT',
       #'ACCESSIBLE_SEATING_DETAIL', 'ADA_PHONE', 'ADA_CUSTOM_COPY',
       #'ADA_HOURS', 'ACCESSIBILITY_INFO', 'API_ONSALE_START_DATETIME',
       #'PLEASE_NOTE', 'IMPORTANT_INFORMATION', 'EVENT_END_LOCAL_DATE'
       ]].copy()

# %%
df.shape
# Out:
# (101781, 3)

# %%
df.isna().sum()
# Out:
# ONSALE_START_DATETIME      716
# ONSALE_END_DATETIME       1354
# MAX_PRICE                42816
# dtype: int64

# %%
# creates a separate df for the datetime that drops rows with NaN values and then resets the index
datetime_df = df.dropna().reset_index(drop=True)
datetime_df.shape
# Out:
# (57693, 3)

# %%
datetime_df.head()
# Out:
#   ONSALE_START_DATETIME   ONSALE_END_DATETIME  MAX_PRICE
# 0  2025-01-20T21:00:00Z  2025-03-02T06:00:00Z      29.34
# 1  2025-01-20T21:00:00Z  2025-03-09T06:00:00Z      29.34
# 2  2025-01-31T15:00:00Z  2025-10-04T02:00:00Z      39.50
# 3  2025-01-20T21:00:00Z  2025-03-30T02:30:00Z      29.34
# 4  2025-01-20T21:00:00Z  2025-03-08T06:45:00Z      19.04

# %%
# convert columns to datetime objects and keep only the date and hours
datetime_df['ONSALE_START_DATETIME'] = pd.to_datetime(datetime_df['ONSALE_START_DATETIME']).dt.strftime('%Y-%m-%d %H')
datetime_df['ONSALE_END_DATETIME'] = pd.to_datetime(datetime_df['ONSALE_END_DATETIME']).dt.strftime('%Y-%m-%d %H')

# %%
datetime_df.head()
# Out:
#   ONSALE_START_DATETIME ONSALE_END_DATETIME  MAX_PRICE
# 0         2025-01-20 21       2025-03-02 06      29.34
# 1         2025-01-20 21       2025-03-09 06      29.34
# 2         2025-01-31 15       2025-10-04 02      39.50
# 3         2025-01-20 21       2025-03-30 02      29.34
# 4         2025-01-20 21       2025-03-08 06      19.04

# %%
ax = datetime_df['ONSALE_START_DATETIME'].value_counts().head(30).plot(kind='bar', title='Top 30 most common sale start dates with hours')
ax.set_xlabel('Dates with hours')
ax.set_ylabel('# of events')
# Out:
# Text(0, 0.5, '# of events')

# %% [markdown]
# January 5 2025 at 8 PM and August 20 2024 at 5 PM were by far the most common times for sales to start. January, October, and November seem to be the most common months.

# %%
ax = datetime_df['ONSALE_END_DATETIME'].value_counts().head(30).plot(kind='bar', title='Top 30 most common sale end dates with hours')
ax.set_xlabel('Dates with hours')
ax.set_ylabel('# of events')
# Out:
# Text(0, 0.5, '# of events')

# %% [markdown]
# The sales end dates are far more evenly distributed compared to the sales start dates.

# %%
mins = df[df['MAX_PRICE'] <= 500]
ax = mins['MAX_PRICE'].plot(kind='hist', bins=20, title='Prices up to $500')
ax.set_xlabel('Price by USD $')
# Out:
# Text(0.5, 0, 'Price by USD $')

# %% [markdown]
# The top most common price for tickets is about $25, followed by $20, and then very surprisingly $0. This could be bad data, but I suspect they are actually free tickets given away by venues in order to inflate attendance numbers for events. I broke up the ticket prices due to extreme outliers. This visualization shows tickets up to $500.

# %%
mids = df[(df['MAX_PRICE'] > 500) & (df['MAX_PRICE'] < 5000)]
ax = mids['MAX_PRICE'].plot(kind='hist', bins=20, title='Prices between \$500  & \$5000')
ax.set_xlabel('Price by USD $')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# /var/folders/d3/gvkrf42n6cs_vbsl97177w3m0000gn/T/ipykernel_94700/3345489674.py:2: SyntaxWarning: invalid escape sequence '\$'
#   ax = mids['MAX_PRICE'].plot(kind='hist', bins=20, title='Prices between \$500  & \$5000')
# Text(0.5, 0, 'Price by USD $')

# %% [markdown]
# This visualization shows tickets above \$500 dollars and under \$5000. The cheaper tickets are more popular but we see a big rise in popularity in tickets around $1600. This could possibly be the prices for floor seats for many events.

# %%
maxs = df[df['MAX_PRICE'] >= 5000]
ax = maxs['MAX_PRICE'].plot(kind='hist', bins=20, title='Prices $5000 and above')
ax.set_xlabel('Price by USD $')
# Out:
# Text(0.5, 0, 'Price by USD $')

# %% [markdown]
# These are the tickets $5000 and up. There seem to be 2 extreme outliers which made the visualizations for all prices hard to see, and that is the highest price for all tickets in the dataset, a single ticket for $21,000. There is also another ticket for nearly $18,000. Besides those 2, no other tickets even reach $14,000.

# %%
# convert any non-string values in 'ONSALE_START_DATETIME' to NaT
datetime_df['ONSALE_START_DATETIME'] = pd.to_datetime(datetime_df['ONSALE_START_DATETIME'], errors='coerce')

# drop any rows where the 'ONSALE_START_DATETIME' is NaT
datetime_df = datetime_df.dropna(subset=['ONSALE_START_DATETIME'])

plt.figure(figsize=(12, 6))
plt.scatter(datetime_df['ONSALE_START_DATETIME'], datetime_df['MAX_PRICE'], alpha=0.5, color='blue')
plt.title('MAX_PRICE vs ONSALE_START_DATETIME')
plt.xlabel('Start of sale by year')
plt.ylabel('Max Price (USD)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# There are some outliers with the sale starts in this data, there is one in 2018 and then a few sales in between 2019 and 2023. The vast majority of this data is focused on 2024 and 2025. There is another outlier of a sale starting in 2026.
#
# It seems prices begin to rise mid 2024 throughout the rest of the year and start to drop as it goes deeper into 2025.

# %%
# convert any non-string values in 'ONSALE_END_DATETIME' to NaT
datetime_df['ONSALE_END_DATETIME'] = pd.to_datetime(datetime_df['ONSALE_END_DATETIME'], errors='coerce')

# drop any rows where the 'ONSALE_END_DATETIME' is NaT
datetime_df = datetime_df.dropna(subset=['ONSALE_END_DATETIME'])

plt.figure(figsize=(12, 6))
plt.scatter(datetime_df['ONSALE_END_DATETIME'], datetime_df['MAX_PRICE'], alpha=0.5, color='red')
plt.title('MAX_PRICE vs ONSALE_END_DATETIME')
plt.xlabel('Sale End Date')
plt.ylabel('Max Price (USD)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# For the sale end dates, there is only one sample before 2024 and there is one outlier all the way in 2030. There are hardly any samples before 2025, with the vast majority of the data focused in 2025 and continuing into just before 2027.
#
# It seems no surprise that all the highest prices are where all the concentration of samples are. There simply are more samples so I think it's logical that more high prices appear there.

# %%
# ensure the datetime columns are correctly formatted
datetime_df['ONSALE_START_DATETIME'] = pd.to_datetime(datetime_df['ONSALE_START_DATETIME'], errors='coerce')
datetime_df['ONSALE_END_DATETIME'] = pd.to_datetime(datetime_df['ONSALE_END_DATETIME'], errors='coerce')

# drop rows where either of the datetime columns has NaT (optional)
datetime_df = datetime_df.dropna(subset=['ONSALE_START_DATETIME', 'ONSALE_END_DATETIME'])

# sort the dataframe by the start datetime
datetime_df = datetime_df.sort_values(by='ONSALE_START_DATETIME')

plt.figure(figsize=(12, 6))
plt.plot(datetime_df['ONSALE_START_DATETIME'], datetime_df['ONSALE_END_DATETIME'], alpha=0.6, color='green')
plt.title('ONSALE_START_DATETIME vs ONSALE_END_DATETIME')
plt.xlabel('Sale Start Date')
plt.ylabel('Sale End Date')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# All the sale start dates and end dates are concentrated around 2024 and 2025. We also have the extreme outliers of a sale start date in 2018 and a sale end date in 2030.

# %%
# filter out prices above $5000
filtered_df = datetime_df[datetime_df['MAX_PRICE'] <= 500]

plt.figure(figsize=(12, 6))
plt.scatter(filtered_df['ONSALE_START_DATETIME'], filtered_df['MAX_PRICE'], alpha=0.5, color='blue')
plt.title('MAX_PRICE vs ONSALE_START_DATETIME below $500')
plt.xlabel('Sale Start Date')
plt.ylabel('Max Price (USD)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# This visualization is filtering out the outliers of max price by keeping below $500 in order to have a closer look at the sale start outliers. The sale start outliers are not zero, which I wanted to see in the case that it was leftover bad data or that it was some form of free tickets, such as a giveaway.

# %%
# filter out prices above $5000
filtered_df = datetime_df[datetime_df['MAX_PRICE'] <= 500]

plt.figure(figsize=(12, 6))
plt.scatter(filtered_df['ONSALE_END_DATETIME'], filtered_df['MAX_PRICE'], alpha=0.5, color='red')
plt.title('MAX_PRICE vs ONSALE_END_DATETIME below $500)')
plt.xlabel('Sale end Date')
plt.ylabel('Max Price (USD)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# This visualization is also filtering out prices above $500 to get a closer look at the other prices. I see that the outliers for the sale end dates are also not $0 which is how it might have appeared on the previous visualizations. Not even the sale that ends in 2030 has zero dollar price.
